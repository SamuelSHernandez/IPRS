# %% [markdown]
# # Survey Metrics Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt
import logging as log

# %%
from filter_test_by_category.filter_dataframe_by_category import filter_dataframe_by_category
from plot_true_false_distribution.plot_true_false_distribution import plot_true_false_distribution
from plot_ordinal_distribution.plot_ordinal_distribution import plot_ordinal_distribution

# %%
# Configure the logging module
log.basicConfig(level=log.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# %% [markdown]
# > Helper Functions

# %%
# Specify the paths to the CSV files
survey_responses = "survey_responses.csv"
survey_questions = "../Data/survey_questions.csv"
survey_questions_category = "../Data/survey_questions_category.csv"
def load_csv(file_path):
    try:
        df = pd.read_csv(file_path)
        print(f"CSV file '{file_path}' successfully loaded into DataFrame.")
        return df
    except (FileNotFoundError, pd.errors.EmptyDataError, pd.errors.ParserError) as e:
        print(f"Error: {str(e)}")

# Load CSV files with error handling
df_survey_responses = load_csv(survey_responses)
df_survey_questions = load_csv(survey_questions)
df_survey_questions_category = load_csv(survey_questions_category)

# Convert 'question_id' to the same data type in both DataFrames
df_survey_responses['question_id'] = df_survey_responses['question_id'].astype(str)
df_survey_questions['question_id'] = df_survey_questions['question_id'].astype(str)

# Merge the DataFrames based on common keys
df_merged = pd.merge(df_survey_responses, df_survey_questions, on='question_id')
df_merged = pd.merge(df_merged, df_survey_questions_category, left_on='category_id', right_on='id')

# %% [markdown]
# ## Mission and Dicipleship

# %%
# Filter the DataFrame based on the desired question category
filtered_category = "Mission and Dicipleship"
filtered_df = filter_dataframe_by_category(df_merged, filtered_category)

# %%
# Plot the distribution of true and false data
plot_true_false_distribution(filtered_category, filtered_df)

# %% [markdown]
# ## Committees and Official Sessions

# %%
# Filter the DataFrame based on the desired question category
filtered_category = "Committees and Official Sessions"
filtered_df = filter_dataframe_by_category(df_merged, filtered_category)

# %%
# Plot the distribution of true and false data
plot_true_false_distribution(filtered_category, filtered_df)
# Plot the distribution of ordinal data
plot_ordinal_distribution(filtered_category, filtered_df)

# %% [markdown]
# ## Action follow-up and communication

# %%
# Filter the DataFrame based on the desired question category
filtered_category = "Action follow-up and communication"
filtered_df = filter_dataframe_by_category(df_merged, filtered_category)

# Plot the distribution of ordinal data
plot_ordinal_distribution(filtered_category, filtered_df)
# Out:
# All answers for questions in the category 'Action follow-up and communication':
#     question_id                                           question answer
# 138     7625390  Is action follow-up assigned and recorded in t...      0
# 139     7625390  Is action follow-up assigned and recorded in t...      2
# 140     7625390  Is action follow-up assigned and recorded in t...      2
# 141     7625390  Is action follow-up assigned and recorded in t...      3
# 142     7625390  Is action follow-up assigned and recorded in t...      3
# 143     7625390  Is action follow-up assigned and recorded in t...      3
# 144     7625393  Are voted action numbers included in the follo...      0
# 145     7625393  Are voted action numbers included in the follo...      2
# 146     7625393  Are voted action numbers included in the follo...      3
# 147     7625393  Are voted action numbers included in the follo...      3
# 148     7625393  Are voted action numbers included in the follo...      3
# 149     7625393  Are voted action numbers included in the follo...      3
# 150     7625394  Is the date the action was taken included in t...      0
# 151     7625394  Is the date the action was taken included in t...      2
# 152     7625394  Is the date the action was taken included in t...      1
# 153     7625394  Is the date the action was taken included in t...      3
# 154     7625394  Is the date the action was taken included in t...      3
# 155     7625394  Is the date the action was taken included in t...      3
# 156     7625399  Is the action wording included in the follow-u...      0
# 157     7625399  Is the action wording included in the follow-u...      2
# 158     7625399  Is the action wording included in the follow-u...      0
# 159     7625399  Is the action wording included in the follow-u...      3
# 160     7625399  Is the action wording included in the follow-u...      3
# 161     7625399  Is the action wording included in the follow-u...      3
# 162     7625398  Is action follow-up recorded in writing and ke...      0
# 163     7625398  Is action follow-up recorded in writing and ke...      2
# 164     7625398  Is action follow-up recorded in writing and ke...      3
# 165     7625398  Is action follow-up recorded in writing and ke...      3
# 166     7625398  Is action follow-up recorded in writing and ke...      2
# 167     7625398  Is action follow-up recorded in writing and ke...      3
# 168     7625397  Is follow-up reported at the next committee me...      0
# 169     7625397  Is follow-up reported at the next committee me...      2
# 170     7625397  Is follow-up reported at the next committee me...      2
# 171     7625397  Is follow-up reported at the next committee me...      3
# 172     7625397  Is follow-up reported at the next committee me...      3
# 173     7625397  Is follow-up reported at the next committee me...      3

# %% [markdown]
# ## Official Sessions/Constituency Meetings

# %%
# Filter the DataFrame based on the desired question category
filtered_category = "Official Sessions/Constituency Meetings"
filtered_df = filter_dataframe_by_category(df_merged, filtered_category)

# Plot the distribution of true and false data
plot_true_false_distribution(filtered_category, filtered_df)
# Out:
# All answers for questions in the category 'Official Sessions/Constituency Meetings':
#     question_id                                           question answer
# 321     7625400  Are official session announcements published a...   True
# 322     7625400  Are official session announcements published a...   True
# 323     7625400  Are official session announcements published a...   True
# 324     7625400  Are official session announcements published a...   True
# 325     7625400  Are official session announcements published a...   True
# ..          ...                                                ...    ...
# 382     7625405  Are worksheets prepared for the Credentials an...   True
# 383     7625405  Are worksheets prepared for the Credentials an...   True
# 384     7625405  Are worksheets prepared for the Credentials an...   True
# 385     7625405  Are worksheets prepared for the Credentials an...   True
# 386     7625405  Are worksheets prepared for the Credentials an...   True
#
# [66 rows x 3 columns]

# %% [markdown]
# ## References, Policies, and Manuals

# %%
# Filter the DataFrame based on the desired question category
filtered_category = "References, Policies, and Manuals"
filtered_df = filter_dataframe_by_category(df_merged, filtered_category)

# Plot the distribution of true and false data
plot_true_false_distribution(filtered_category, filtered_df)
# Plot the distribution of ordinal data
plot_ordinal_distribution(filtered_category, filtered_df)
# Out:
# All answers for questions in the category 'References, Policies, and Manuals':
#     question_id                                           question answer
# 174     7625489  In general, how often is the parent organizati...      0
# 175     7625489  In general, how often is the parent organizati...      1
# 176     7625489  In general, how often is the parent organizati...      3
# 177     7625489  In general, how often is the parent organizati...      3
# 178     7625489  In general, how often is the parent organizati...      3
# 179     7625489  In general, how often is the parent organizati...      3
# 180     7625572            Do you follow published Rules of Order?      2
# 181     7625572            Do you follow published Rules of Order?      3
# 182     7625572            Do you follow published Rules of Order?      2
# 183     7625572            Do you follow published Rules of Order?      3
# 184     7625572            Do you follow published Rules of Order?      3
# 185     7625572            Do you follow published Rules of Order?      3
# 186     7625497  Is a current copy of the General Conference Wo...   True
# 187     7625497  Is a current copy of the General Conference Wo...   True
# 188     7625497  Is a current copy of the General Conference Wo...   True
# 189     7625497  Is a current copy of the General Conference Wo...   True
# 190     7625497  Is a current copy of the General Conference Wo...   True
# 191     7625497  Is a current copy of the General Conference Wo...   True
# 192     7625480  Is a current copy of the parent organization's...   True
# 193     7625480  Is a current copy of the parent organization's...   True
# 194     7625480  Is a current copy of the parent organization's...   True
# 195     7625480  Is a current copy of the parent organization's...   True
# 196     7625480  Is a current copy of the parent organization's...   True
# 197     7625480  Is a current copy of the parent organization's...   True
# 198     7625481  Are copies of the working policies/operating p...   True
# 199     7625481  Are copies of the working policies/operating p...  False
# 200     7625481  Are copies of the working policies/operating p...   True
# 201     7625481  Are copies of the working policies/operating p...   True
# 202     7625481  Are copies of the working policies/operating p...   True
# 203     7625481  Are copies of the working policies/operating p...   True
# 204     7625667  Are copies of the working policies/operating p...   True
# 205     7625667  Are copies of the working policies/operating p...  False
# 206     7625667  Are copies of the working policies/operating p...  False
# 207     7625667  Are copies of the working policies/operating p...   True
# 208     7625667  Are copies of the working policies/operating p...   True
# 209     7625667  Are copies of the working policies/operating p...   True
# 210     7625496  Is a current copy of the GC ISE Handbook avail...   True
# 211     7625496  Is a current copy of the GC ISE Handbook avail...  False
# 212     7625496  Is a current copy of the GC ISE Handbook avail...   True
# 213     7625496  Is a current copy of the GC ISE Handbook avail...   True
# 214     7625496  Is a current copy of the GC ISE Handbook avail...   True
# 215     7625496  Is a current copy of the GC ISE Handbook avail...   True
# 216     7625495  Is a current copy of the Annual Statistical Re...   True
# 217     7625495  Is a current copy of the Annual Statistical Re...  False
# 218     7625495  Is a current copy of the Annual Statistical Re...  False
# 219     7625495  Is a current copy of the Annual Statistical Re...   True
# 220     7625495  Is a current copy of the Annual Statistical Re...   True
# 221     7625495  Is a current copy of the Annual Statistical Re...   True
# 222     7625498  Is a personal copy of the Church Manual (print...   True
# 223     7625498  Is a personal copy of the Church Manual (print...  False
# 224     7625498  Is a personal copy of the Church Manual (print...  False
# 225     7625498  Is a personal copy of the Church Manual (print...   True
# 226     7625498  Is a personal copy of the Church Manual (print...   True
# 227     7625498  Is a personal copy of the Church Manual (print...   True

# %% [markdown]
# ## Statistical Reports

# %%
# Filter the DataFrame based on the desired question category
filtered_category = "References, Policies, and Manuals"
filtered_df = filter_dataframe_by_category(df_merged, filtered_category)
# Out:
# All answers for questions in the category 'References, Policies, and Manuals':
#     question_id                                           question answer
# 174     7625489  In general, how often is the parent organizati...      0
# 175     7625489  In general, how often is the parent organizati...      1
# 176     7625489  In general, how often is the parent organizati...      3
# 177     7625489  In general, how often is the parent organizati...      3
# 178     7625489  In general, how often is the parent organizati...      3
# 179     7625489  In general, how often is the parent organizati...      3
# 180     7625572            Do you follow published Rules of Order?      2
# 181     7625572            Do you follow published Rules of Order?      3
# 182     7625572            Do you follow published Rules of Order?      2
# 183     7625572            Do you follow published Rules of Order?      3
# 184     7625572            Do you follow published Rules of Order?      3
# 185     7625572            Do you follow published Rules of Order?      3
# 186     7625497  Is a current copy of the General Conference Wo...   True
# 187     7625497  Is a current copy of the General Conference Wo...   True
# 188     7625497  Is a current copy of the General Conference Wo...   True
# 189     7625497  Is a current copy of the General Conference Wo...   True
# 190     7625497  Is a current copy of the General Conference Wo...   True
# 191     7625497  Is a current copy of the General Conference Wo...   True
# 192     7625480  Is a current copy of the parent organization's...   True
# 193     7625480  Is a current copy of the parent organization's...   True
# 194     7625480  Is a current copy of the parent organization's...   True
# 195     7625480  Is a current copy of the parent organization's...   True
# 196     7625480  Is a current copy of the parent organization's...   True
# 197     7625480  Is a current copy of the parent organization's...   True
# 198     7625481  Are copies of the working policies/operating p...   True
# 199     7625481  Are copies of the working policies/operating p...  False
# 200     7625481  Are copies of the working policies/operating p...   True
# 201     7625481  Are copies of the working policies/operating p...   True
# 202     7625481  Are copies of the working policies/operating p...   True
# 203     7625481  Are copies of the working policies/operating p...   True
# 204     7625667  Are copies of the working policies/operating p...   True
# 205     7625667  Are copies of the working policies/operating p...  False
# 206     7625667  Are copies of the working policies/operating p...  False
# 207     7625667  Are copies of the working policies/operating p...   True
# 208     7625667  Are copies of the working policies/operating p...   True
# 209     7625667  Are copies of the working policies/operating p...   True
# 210     7625496  Is a current copy of the GC ISE Handbook avail...   True
# 211     7625496  Is a current copy of the GC ISE Handbook avail...  False
# 212     7625496  Is a current copy of the GC ISE Handbook avail...   True
# 213     7625496  Is a current copy of the GC ISE Handbook avail...   True
# 214     7625496  Is a current copy of the GC ISE Handbook avail...   True
# 215     7625496  Is a current copy of the GC ISE Handbook avail...   True
# 216     7625495  Is a current copy of the Annual Statistical Re...   True
# 217     7625495  Is a current copy of the Annual Statistical Re...  False
# 218     7625495  Is a current copy of the Annual Statistical Re...  False
# 219     7625495  Is a current copy of the Annual Statistical Re...   True
# 220     7625495  Is a current copy of the Annual Statistical Re...   True
# 221     7625495  Is a current copy of the Annual Statistical Re...   True
# 222     7625498  Is a personal copy of the Church Manual (print...   True
# 223     7625498  Is a personal copy of the Church Manual (print...  False
# 224     7625498  Is a personal copy of the Church Manual (print...  False
# 225     7625498  Is a personal copy of the Church Manual (print...   True
# 226     7625498  Is a personal copy of the Church Manual (print...   True
# 227     7625498  Is a personal copy of the Church Manual (print...   True

# %% [markdown]
# ## Statistical Reports

# %%
# Filter the DataFrame based on the desired question category
filtered_category = "Statistical Reports"
filtered_df = filter_dataframe_by_category(df_merged, filtered_category)

# %%
# Plot the distribution of true and false data
plot_true_false_distribution(filtered_category, filtered_df)
# Out:
# All answers for questions in the category 'Statistical Reports':
#     question_id                                           question answer
# 387     7625713  Are the entity's quarterly statistical reports...   True
# 388     7625713  Are the entity's quarterly statistical reports...  False
# 389     7625713  Are the entity's quarterly statistical reports...   True
# 390     7625713  Are the entity's quarterly statistical reports...   True
# 391     7625713  Are the entity's quarterly statistical reports...   True
# 392     7625713  Are the entity's quarterly statistical reports...   True
# 393     7625758  Are you using Adventist Church Membership Soft...    NaN
# 394     7625758  Are you using Adventist Church Membership Soft...  False
# 395     7625758  Are you using Adventist Church Membership Soft...   True
# 396     7625758  Are you using Adventist Church Membership Soft...   True
# 397     7625758  Are you using Adventist Church Membership Soft...   True
# 398     7625758  Are you using Adventist Church Membership Soft...   True
# 399     7625760            Is there a designated ACMS Coordinator?   True
# 400     7625760            Is there a designated ACMS Coordinator?  False
# 401     7625760            Is there a designated ACMS Coordinator?   True
# 402     7625760            Is there a designated ACMS Coordinator?   True
# 403     7625760            Is there a designated ACMS Coordinator?   True
# 404     7625760            Is there a designated ACMS Coordinator?   True
# 405     7625757  If using ACMS, are the membership numbers in A...  False
# 406     7625757  If using ACMS, are the membership numbers in A...   True
# 407     7625757  If using ACMS, are the membership numbers in A...   True
# 408     7625757  If using ACMS, are the membership numbers in A...   True
# 409     7625757  If using ACMS, are the membership numbers in A...   True

# %% [markdown]
# ## Yearbook

# %%
filtered_category = "Yearbook"
filtered_df = filter_dataframe_by_category(df_merged, filtered_category)

# %%
# Plot the distribution of true and false data
plot_true_false_distribution(filtered_category, filtered_df)

# %% [markdown]
# ## Personnel Data

# %%
filtered_category = "Personnel Data"
filtered_df = filter_dataframe_by_category(df_merged, filtered_category)
# Out:
# All answers for questions in the category 'Personnel Data':
#     question_id                                           question answer
# 434     7625850                  Is there a list of all employees?   True
# 435     7625850                  Is there a list of all employees?   True
# 436     7625850                  Is there a list of all employees?   True
# 437     7625850                  Is there a list of all employees?   True
# 438     7625850                  Is there a list of all employees?   True
# ..          ...                                                ...    ...
# 518     7625851  Are originals scanned and archived digitally, ...   True
# 519     7625851  Are originals scanned and archived digitally, ...  False
# 520     7625851  Are originals scanned and archived digitally, ...   True
# 521     7625851  Are originals scanned and archived digitally, ...  False
# 522     7625851  Are originals scanned and archived digitally, ...  False
#
# [89 rows x 3 columns]

# %%
# Plot the distribution of true and false data
plot_true_false_distribution(filtered_category, filtered_df)

# %% [markdown]
# ## Credentials and Licenses

# %%
filtered_category = "Credentials and Licenses"
filtered_df = filter_dataframe_by_category(df_merged, filtered_category)
# Out:
# All answers for questions in the category 'Credentials and Licenses':
#     question_id                                           question  \
# 228     7626259    How many employees does your organization have?
# 229     7626259    How many employees does your organization have?
# 230     7626259    How many employees does your organization have?
# 231     7626259    How many employees does your organization have?
# 232     7626259    How many employees does your organization have?
# 233     7626259    How many employees does your organization have?
# 234     7626226       Do all workers have credentials or licenses?
# 235     7626226       Do all workers have credentials or licenses?
# 236     7626226       Do all workers have credentials or licenses?
# 237     7626226       Do all workers have credentials or licenses?
# 238     7626226       Do all workers have credentials or licenses?
# 239     7626226       Do all workers have credentials or licenses?
# 240     7626230     Are credentials and licenses issued each term?
# 241     7626230     Are credentials and licenses issued each term?
# 242     7626230     Are credentials and licenses issued each term?
# 243     7626230     Are credentials and licenses issued each term?
# 244     7626230     Are credentials and licenses issued each term?
# 245     7626230     Are credentials and licenses issued each term?
# 246     7626358  Does a committee review and approve all creden...
# 247     7626358  Does a committee review and approve all creden...
# 248     7626358  Does a committee review and approve all creden...
# 249     7626358  Does a committee review and approve all creden...
# 250     7626358  Does a committee review and approve all creden...
# 251     7626358  Does a committee review and approve all creden...
# 252     7626357  Does an officer sign the credentials and licen...
# 253     7626357  Does an officer sign the credentials and licen...
# 254     7626357  Does an officer sign the credentials and licen...
# 255     7626357  Does an officer sign the credentials and licen...
# 256     7626357  Does an officer sign the credentials and licen...
# 257     7626357  Does an officer sign the credentials and licen...
# 258     7626356  Does each worker have a separate record with p...
# 259     7626356  Does each worker have a separate record with p...
# 260     7626356  Does each worker have a separate record with p...
# 261     7626356  Does each worker have a separate record with p...
# 262     7626356  Does each worker have a separate record with p...
# 263     7626356  Does each worker have a separate record with p...
# 264     7626229   Are employment ID cards issued to all employees?
# 265     7626229   Are employment ID cards issued to all employees?
# 266     7626229   Are employment ID cards issued to all employees?
# 267     7626229   Are employment ID cards issued to all employees?
# 268     7626229   Are employment ID cards issued to all employees?
# 269     7626229   Are employment ID cards issued to all employees?
# 270     7626228                Are ID cards with photographs used?
# 271     7626228                Are ID cards with photographs used?
# 272     7626228                Are ID cards with photographs used?
# 273     7626228                Are ID cards with photographs used?
# 274     7626228                Are ID cards with photographs used?
# 275     7626228                Are ID cards with photographs used?
# 276     7626227  Are employment ID cards issued to probationary...
# 277     7626227  Are employment ID cards issued to probationary...
# 278     7626227  Are employment ID cards issued to probationary...
# 279     7626227  Are employment ID cards issued to probationary...
# 280     7626227  Are employment ID cards issued to probationary...
# 281     7626227  Are employment ID cards issued to probationary...
#
#            answer
# 228  Less than 20
# 229  Less than 20
# 230  More than 20
# 231  More than 20
# 232  Less than 20
# 233  Less than 20
# 234          True
# 235          True
# 236          True
# 237          True
# 238          True
# 239          True
# 240          True
# 241          True
# 242         False
# 243          True
# 244          True
# 245          True
# 246          True
# 247          True
# 248          True
# 249          True
# 250         False
# 251          True
# 252          True
# 253          True
# 254         False
# 255          True
# 256         False
# 257          True
# 258          True
# 259          True
# 260          True
# 261          True
# 262          True
# 263          True
# 264         False
# 265         False
# 266          True
# 267          True
# 268          True
# 269          True
# 270         False
# 271         False
# 272          True
# 273          True
# 274          True
# 275          True
# 276         False
# 277         False
# 278          True
# 279          True
# 280         False
# 281          True

# %%
# Plot the distribution of true and false data
plot_true_false_distribution(filtered_category, filtered_df)

# %% [markdown]
# ## Call Processing

# %%
filtered_category = "Call Processing"
filtered_df = filter_dataframe_by_category(df_merged, filtered_category)
# Out:
# All answers for questions in the category 'Call Processing':
#     question_id                                           question answer
# 523     7626718  Are there stated procedures for calling regula...  False
# 524     7626718  Are there stated procedures for calling regula...  False
# 525     7626718  Are there stated procedures for calling regula...   True
# 526     7626718  Are there stated procedures for calling regula...   True
# 527     7626718  Are there stated procedures for calling regula...  False
# 528     7626718  Are there stated procedures for calling regula...   True
# 529     7626715  Are there stated procedures for calling worker...  False
# 530     7626715  Are there stated procedures for calling worker...  False
# 531     7626715  Are there stated procedures for calling worker...   True
# 532     7626715  Are there stated procedures for calling worker...   True
# 533     7626715  Are there stated procedures for calling worker...   True
# 534     7626715  Are there stated procedures for calling worker...   True
# 535     7626717  Are there stated procedures for calling volunt...  False
# 536     7626717  Are there stated procedures for calling volunt...   True
# 537     7626717  Are there stated procedures for calling volunt...   True
# 538     7626717  Are there stated procedures for calling volunt...   True
# 539     7626717  Are there stated procedures for calling volunt...  False
# 540     7626717  Are there stated procedures for calling volunt...   True
# 541     7626716  Is there a designated director of Adventist Vo...  False
# 542     7626716  Is there a designated director of Adventist Vo...   True
# 543     7626716  Is there a designated director of Adventist Vo...   True
# 544     7626716  Is there a designated director of Adventist Vo...   True
# 545     7626716  Is there a designated director of Adventist Vo...   True
# 546     7626716  Is there a designated director of Adventist Vo...   True

# %%
# Plot the distribution of true and false data
plot_true_false_distribution(filtered_category, filtered_df)

# %% [markdown]
# ## Working Lists/Mailing Lists

# %%
filtered_category = "Working Lists/Mailing Lists"
filtered_df = filter_dataframe_by_category(df_merged, filtered_category)
# Out:
# All answers for questions in the category 'Working Lists/Mailing Lists':
#     question_id                                           question answer
# 547     7626743  Is there a directory of your organization with...  False
# 548     7626743  Is there a directory of your organization with...   True
# 549     7626743  Is there a directory of your organization with...   True
# 550     7626743  Is there a directory of your organization with...   True
# 551     7626743  Is there a directory of your organization with...   True
# 552     7626743  Is there a directory of your organization with...   True
# 553     7626744  Is there a directory of your subsidiary organi...  False
# 554     7626744  Is there a directory of your subsidiary organi...   True
# 555     7626744  Is there a directory of your subsidiary organi...   True
# 556     7626744  Is there a directory of your subsidiary organi...   True
# 557     7626744  Is there a directory of your subsidiary organi...  False
# 558     7626744  Is there a directory of your subsidiary organi...   True
# 559     7626745  Is there a directory of your parent organizati...  False
# 560     7626745  Is there a directory of your parent organizati...   True
# 561     7626745  Is there a directory of your parent organizati...   True
# 562     7626745  Is there a directory of your parent organizati...   True
# 563     7626745  Is there a directory of your parent organizati...   True
# 564     7626745  Is there a directory of your parent organizati...   True
# 565     7626746  Is there a directory  of all institutional boa...  False
# 566     7626746  Is there a directory  of all institutional boa...   True
# 567     7626746  Is there a directory  of all institutional boa...  False
# 568     7626746  Is there a directory  of all institutional boa...   True
# 569     7626746  Is there a directory  of all institutional boa...  False
# 570     7626746  Is there a directory  of all institutional boa...   True
# 571     7626747  Are there terms of reference for all instituti...  False
# 572     7626747  Are there terms of reference for all instituti...   True
# 573     7626747  Are there terms of reference for all instituti...   True
# 574     7626747  Are there terms of reference for all instituti...   True
# 575     7626747  Are there terms of reference for all instituti...   True
# 576     7626747  Are there terms of reference for all instituti...   True
# 577     7626749  Are there terms of references for all standing...  False
# 578     7626749  Are there terms of references for all standing...   True
# 579     7626749  Are there terms of references for all standing...   True
# 580     7626749  Are there terms of references for all standing...   True
# 581     7626749  Are there terms of references for all standing...  False
# 582     7626749  Are there terms of references for all standing...   True
# 583     7626748  Is there a list of all standing committees, in...  False
# 584     7626748  Is there a list of all standing committees, in...   True
# 585     7626748  Is there a list of all standing committees, in...   True
# 586     7626748  Is there a list of all standing committees, in...   True
# 587     7626748  Is there a list of all standing committees, in...   True
# 588     7626748  Is there a list of all standing committees, in...   True
# 589     7626751  Is there a master schedule of your organizatio...  False
# 590     7626751  Is there a master schedule of your organizatio...   True
# 591     7626751  Is there a master schedule of your organizatio...  False
# 592     7626751  Is there a master schedule of your organizatio...   True
# 593     7626751  Is there a master schedule of your organizatio...   True
# 594     7626751  Is there a master schedule of your organizatio...   True
# 595     7626750  Are job descriptions maintained for the Secret...  False
# 596     7626750  Are job descriptions maintained for the Secret...   True
# 597     7626750  Are job descriptions maintained for the Secret...   True
# 598     7626750  Are job descriptions maintained for the Secret...   True
# 599     7626750  Are job descriptions maintained for the Secret...   True
# 600     7626750  Are job descriptions maintained for the Secret...   True

# %%
# Plot the distribution of true and false data
plot_true_false_distribution(filtered_category, filtered_df)

# %% [markdown]
# ## Office Facilities

# %%
filtered_category = "Office Facilities"
filtered_df = filter_dataframe_by_category(df_merged, filtered_category)
# Out:
# All answers for questions in the category 'Office Facilities':
#     question_id                                           question answer
# 601     7626781      Do you have disaster policies and procedures?  False
# 602     7626781      Do you have disaster policies and procedures?   True
# 603     7626781      Do you have disaster policies and procedures?   True
# 604     7626781      Do you have disaster policies and procedures?   True
# 605     7626781      Do you have disaster policies and procedures?   True
# 606     7626781      Do you have disaster policies and procedures?   True
# 607     7626771  Are the disaster policies and procedures revie...  False
# 608     7626771  Are the disaster policies and procedures revie...   True
# 609     7626771  Are the disaster policies and procedures revie...   True
# 610     7626771  Are the disaster policies and procedures revie...   True
# 611     7626771  Are the disaster policies and procedures revie...   True
# 612     7626771  Are the disaster policies and procedures revie...   True
# 613     7626772  Are electronic records addressed in the disast...  False
# 614     7626772  Are electronic records addressed in the disast...   True
# 615     7626772  Are electronic records addressed in the disast...   True
# 616     7626772  Are electronic records addressed in the disast...   True
# 617     7626772  Are electronic records addressed in the disast...   True
# 618     7626772  Are electronic records addressed in the disast...   True
# 619     7626773  Is adequate space provided for Secretariat per...  False
# 620     7626773  Is adequate space provided for Secretariat per...   True
# 621     7626773  Is adequate space provided for Secretariat per...   True
# 622     7626773  Is adequate space provided for Secretariat per...   True
# 623     7626773  Is adequate space provided for Secretariat per...  False
# 624     7626773  Is adequate space provided for Secretariat per...   True
# 625     7626774  Is a fire extinguisher available in the office...  False
# 626     7626774  Is a fire extinguisher available in the office...  False
# 627     7626774  Is a fire extinguisher available in the office...   True
# 628     7626774  Is a fire extinguisher available in the office...   True
# 629     7626774  Is a fire extinguisher available in the office...   True
# 630     7626774  Is a fire extinguisher available in the office...   True

# %%
# Plot the distribution of true and false data
plot_true_false_distribution(filtered_category, filtered_df)

# %% [markdown]
# ## Conference or Mission Assesement

# %%
filtered_category = "Conference or Mission Assesement"
filtered_df = filter_dataframe_by_category(df_merged, filtered_category)
# Out:
# All answers for questions in the category 'Conference or Mission Assesement':
#     question_id                                           question answer
# 631     7626871  Does the conference/mission have a system for ...  False
# 632     7626871  Does the conference/mission have a system for ...   True
# 633     7626871  Does the conference/mission have a system for ...   True
# 634     7626871  Does the conference/mission have a system for ...   True
# 635     7626871  Does the conference/mission have a system for ...  False
# 636     7626871  Does the conference/mission have a system for ...   True
# 637     7626872  Do church membership records include birth/mar...   True
# 638     7626872  Do church membership records include birth/mar...   True
# 639     7626872  Do church membership records include birth/mar...   True
# 640     7626872  Do church membership records include birth/mar...   True
# 641     7626872  Do church membership records include birth/mar...  False
# 642     7626872  Do church membership records include birth/mar...   True
# 643     7626873  Was a church membership audit done within the ...   True
# 644     7626873  Was a church membership audit done within the ...   True
# 645     7626873  Was a church membership audit done within the ...   True
# 646     7626873  Was a church membership audit done within the ...   True
# 647     7626873  Was a church membership audit done within the ...  False
# 648     7626873  Was a church membership audit done within the ...   True
# 649     7626874  Is there a date scheduled for the next church ...   True
# 650     7626874  Is there a date scheduled for the next church ...   True
# 651     7626874  Is there a date scheduled for the next church ...   True
# 652     7626874  Is there a date scheduled for the next church ...   True
# 653     7626874  Is there a date scheduled for the next church ...  False
# 654     7626874  Is there a date scheduled for the next church ...   True
# 655     7626875  Are you using an electronic system for recordi...   True
# 656     7626875  Are you using an electronic system for recordi...   True
# 657     7626875  Are you using an electronic system for recordi...   True
# 658     7626875  Are you using an electronic system for recordi...   True
# 659     7626875  Are you using an electronic system for recordi...  False
# 660     7626875  Are you using an electronic system for recordi...   True
# 661     7626876      Are church membership lists easy to retrieve?   True
# 662     7626876      Are church membership lists easy to retrieve?   True
# 663     7626876      Are church membership lists easy to retrieve?   True
# 664     7626876      Are church membership lists easy to retrieve?   True
# 665     7626876      Are church membership lists easy to retrieve?  False
# 666     7626876      Are church membership lists easy to retrieve?   True
# 667     7626877           Are church clerk records easy to access?   True
# 668     7626877           Are church clerk records easy to access?   True
# 669     7626877           Are church clerk records easy to access?   True
# 670     7626877           Are church clerk records easy to access?   True
# 671     7626877           Are church clerk records easy to access?  False
# 672     7626877           Are church clerk records easy to access?   True
# 673     7626878  Are statistical quarterly membership records e...   True
# 674     7626878  Are statistical quarterly membership records e...   True
# 675     7626878  Are statistical quarterly membership records e...   True
# 676     7626878  Are statistical quarterly membership records e...   True
# 677     7626878  Are statistical quarterly membership records e...  False
# 678     7626878  Are statistical quarterly membership records e...   True

# %%
# Plot the distribution of true and false data
plot_true_false_distribution(filtered_category, filtered_df)
